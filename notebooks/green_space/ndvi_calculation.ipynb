# %% [markdown]
# ## NDVI Raster Collection from Google Earth Engine
# This document provides a step-by-step guide to collecting NDVI (Normalized Difference Vegetation Index) raster data using Google Earth Engine (GEE). NDVI is a widely used index for assessing vegetation health and coverage.

# %%
#!pip install ee
#!pip install geemap
# Out:
# Requirement already satisfied: ee in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (0.2)
# Requirement already satisfied: blessings in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ee) (1.7)
# Requirement already satisfied: six in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from blessings->ee) (1.17.0)
# Collecting geemap
#   Downloading geemap-0.36.6-py3-none-any.whl.metadata (14 kB)
# Collecting anywidget (from geemap)
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Collecting bqplot (from geemap)
#   Downloading bqplot-0.12.45-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting earthengine-api>=1.6.12 (from geemap)
#   Downloading earthengine_api-1.7.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting eerepr>=0.1.0 (from geemap)
#   Downloading eerepr-0.1.2-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: folium>=0.17.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geemap) (0.20.0)
# Collecting geocoder (from geemap)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap)
#   Downloading ipyevents-2.0.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap)
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.19.2 (from geemap)
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: matplotlib in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geemap) (3.10.7)
# Requirement already satisfied: numpy in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geemap) (2.1.3)
# Requirement already satisfied: pandas in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geemap) (2.2.3)
# Collecting plotly (from geemap)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pyperclip (from geemap)
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geemap) (3.0.2.post1)
# Collecting python-box (from geemap)
#   Downloading python_box-7.3.2-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Collecting scooby (from geemap)
#   Downloading scooby-0.11.0-py3-none-any.whl.metadata (15 kB)
# Collecting google-cloud-storage (from earthengine-api>=1.6.12->geemap)
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api>=1.6.12->geemap)
#   Downloading google_api_python_client-2.187.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-auth>=1.4.1 (from earthengine-api>=1.6.12->geemap)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api>=1.6.12->geemap)
#   Downloading google_auth_httplib2-0.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api>=1.6.12->geemap)
#   Downloading httplib2-0.31.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from earthengine-api>=1.6.12->geemap) (2.32.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from folium>=0.17.0->geemap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from folium>=0.17.0->geemap) (3.1.5)
# Requirement already satisfied: xyzservices in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from folium>=0.17.0->geemap) (2025.4.0)
# Collecting ipywidgets (from ipyfilechooser>=0.6.0->geemap)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyter-leaflet<0.21,>=0.20 (from ipyleaflet>=0.19.2->geemap)
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.19.2->geemap)
#   Downloading traittypes-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting psygnal>=0.8.1 (from anywidget->geemap)
#   Downloading psygnal-0.15.0-cp310-cp310-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from anywidget->geemap) (4.15.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from pandas->geemap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geocoder->geemap) (8.3.0)
# Collecting future (from geocoder->geemap)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ratelim (from geocoder->geemap)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from geocoder->geemap) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from matplotlib->geemap) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from plotly->geemap) (2.5.0)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.31.0)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: colorama in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->earthengine-api>=1.6.12->geemap)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->earthengine-api>=1.6.12->geemap)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->earthengine-api>=1.6.12->geemap)
#   Downloading google_crc32c-1.7.1-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from requests->earthengine-api>=1.6.12->geemap) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from requests->earthengine-api>=1.6.12->geemap) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from requests->earthengine-api>=1.6.12->geemap) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from requests->earthengine-api>=1.6.12->geemap) (2025.10.5)
# Requirement already satisfied: decorator in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (6.33.0)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: exceptiongroup in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.6.12->geemap)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\kalmanj\appdata\local\anaconda3\envs\urbanspatial\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Downloading geemap-0.36.6-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 12.0 MB/s eta 0:00:00
# Downloading earthengine_api-1.7.1-py3-none-any.whl (468 kB)
# Downloading eerepr-0.1.2-py3-none-any.whl (9.5 kB)
# Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Downloading bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.5 MB/s eta 0:00:00
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Downloading ipyevents-2.0.4-py3-none-any.whl (102 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/9.9 MB 14.2 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.9 MB 14.2 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 14.0 MB/s eta 0:00:00
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Downloading python_box-7.3.2-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.4 MB/s eta 0:00:00
# Downloading scooby-0.11.0-py3-none-any.whl (19 kB)
# Downloading google_api_python_client-2.187.0-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/14.6 MB 14.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.0/14.6 MB 14.2 MB/s eta 0:00:01
#    ------------------------ --------------- 8.9/14.6 MB 14.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.1/14.6 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 14.2 MB/s eta 0:00:00
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading google_auth_httplib2-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading httplib2-0.31.0-py3-none-any.whl (91 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 13.4 MB/s eta 0:00:00
# Downloading psygnal-0.15.0-cp310-cp310-win_amd64.whl (409 kB)
# Downloading traittypes-0.2.3-py2.py3-none-any.whl (8.1 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.7.1-cp310-cp310-win_amd64.whl (33 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    --------------------------------------- 914.9/914.9 kB 20.4 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 12.3 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: pyperclip, widgetsnbextension, uritemplate, traittypes, scooby, ratelim, python-box, pyasn1, psygnal, proto-plus, plotly, jupyterlab_widgets, jupyter-leaflet, httplib2, googleapis-common-protos, google-crc32c, future, cachetools, rsa, pyasn1-modules, google-resumable-media, geocoder, ipywidgets, google-auth, ipyleaflet, ipyfilechooser, ipyevents, google-auth-httplib2, google-api-core, bqplot, anywidget, google-cloud-core, google-api-python-client, google-cloud-storage, earthengine-api, eerepr, geemap
# Successfully installed anywidget-0.9.21 bqplot-0.12.45 cachetools-6.2.2 earthengine-api-1.7.1 eerepr-0.1.2 future-1.0.0 geemap-0.36.6 geocoder-1.38.1 google-api-core-2.28.1 google-api-python-client-2.187.0 google-auth-2.43.0 google-auth-httplib2-0.2.1 google-cloud-core-2.5.0 google-cloud-storage-3.6.0 google-crc32c-1.7.1 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 httplib2-0.31.0 ipyevents-2.0.4 ipyfilechooser-0.6.0 ipyleaflet-0.20.0 ipywidgets-8.1.8 jupyter-leaflet-0.20.0 jupyterlab_widgets-3.0.16 plotly-6.5.0 proto-plus-1.26.1 psygnal-0.15.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyperclip-1.11.0 python-box-7.3.2 ratelim-0.1.6 rsa-4.9.1 scooby-0.11.0 traittypes-0.2.3 uritemplate-4.2.0 widgetsnbextension-4.0.15

# %% [markdown]
# ## Import nessecary modules

# %%
import ee
import geemap
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import ee
#       2 import geemap
#       3 import geopandas as gpd
#
# File ~\AppData\Local\anaconda3\envs\urbanspatial\lib\site-packages\ee\__init__.py:1
# ----> 1 from .main import main
#
# File ~\AppData\Local\anaconda3\envs\urbanspatial\lib\site-packages\ee\main.py:5
#       3 import subprocess
#       4 import sys
# ----> 5 import blessings
#       6 import re
#       7 import os
#
# File ~\AppData\Local\anaconda3\envs\urbanspatial\lib\site-packages\blessings\__init__.py:5
#       1 """A thin, practical wrapper around terminal coloring, styling, and
#       2 positioning"""
#       4 from contextlib import contextmanager
# ----> 5 import curses
#       6 from curses import setupterm, tigetnum, tigetstr, tparm
#       7 from fcntl import ioctl
#
# File ~\AppData\Local\anaconda3\envs\urbanspatial\lib\curses\__init__.py:13
#       1 """curses
#       2
#       3 The main package for curses support for Python.  Normally used by importing
#    (...)
#      10
#      11 """
# ---> 13 from _curses import *
#      14 import os as _os
#      15 import sys as _sys
#
# ModuleNotFoundError: No module named '_curses'

# %%
# Initially I had to authenticate the API, but now this step is not necessary. Showing for replication purposes. 
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %% [markdown]
# An automated notebook message will provide steps on how to authenticate the Google Earth Engine API.

# %%
# Load Philly boundary file
phillygdf = gpd.read_file("../../data/City_Limits.geojson")

# Convert to Earth Engine geometry
philly_ee = geemap.geopandas_to_ee(phillygdf)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def get_philly_ndvi():
    landsat8 = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2") \
        .filterBounds(philly_ee) \
        .filterDate('2024-06-01', '2024-08-31') \
        .filter(ee.Filter.lt('CLOUD_COVER', 10))  # Relaxed to 15%
    
    def mask_clouds(image):
        qa = image.select('QA_PIXEL')
        # Both bits should be 0 (clear)
        cloud_bit = 1 << 3
        shadow_bit = 1 << 4
        
        # Create masks (True = clear pixel)
        clear_mask = qa.bitwiseAnd(cloud_bit).eq(0) \
                       .And(qa.bitwiseAnd(shadow_bit).eq(0))  # Fixed!
        
        return image.updateMask(clear_mask)
    
    composite = landsat8.map(mask_clouds).median()
    ndvi = composite.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')
    
    return ndvi.clip(philly_ee)

# Re-run
ndvi_image = get_philly_ndvi()

# Check it has data before exporting
# This will fail if no data:
try:
    test_value = ndvi_image.sample(ee.Geometry.Point([-75.16, 39.95]), 30).first().get('NDVI').getInfo()
    print(f"✅ NDVI has data! Sample value: {test_value}")
except:
    print("❌ NDVI has no data - check your code")


# Export NDVI image to GeoTIFF
task = ee.batch.Export.image.toDrive(
    image=ndvi_image,
    description='Philly_NDVI_Summer2024_fixed',
    folder='EarthEngineExports',
    fileNamePrefix='philly_ndvi_2024_summer_fixed',
    scale=30,
    crs='EPSG:2272',
    maxPixels=1e13
)

task.start()

print("✅ Export started with working NDVI!")
print("Monitor at: https://code.earthengine.google.com/tasks")
print(f"Task ID: {task.id}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ NDVI has data! Sample value: 0.06864574551582336
# ✅ Export started with working NDVI!
# Monitor at: https://code.earthengine.google.com/tasks
# Task ID: MKOJAWYTHJAUSVRSVQR6VG24

# %% [markdown]
# ## Resources
# GEE Python Installation Documents - https://developers.google.com/earth-engine/guides/python_install
# GEE Community Tutorials - https://developers.google.com/earth-engine/community/tutorials
